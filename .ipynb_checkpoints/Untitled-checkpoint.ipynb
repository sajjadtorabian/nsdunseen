# %%
import pandas as pd
df = pd.read_csv('subj01/behav/coco_annot_response.tsv', sep='\t')

# %%
df[df['73KID']==2991]
# Out:
#        Unnamed: 0  SUBJECT  SESSION  RUN  TRIAL  73KID  10KID        TIME  \
# 18457       18457        1       25    8     20   2991      2  168.726139
# 18696       18696        1       25   12      9   2991      2  168.744875
# 27710       27710        1       37   12     23   2991      2  246.727823
#
#        ISOLD  ISCORRECT  ...  MEMORYRECENT  MEMORYFIRST  ISOLDCURRENT  \
# 18457      0        1.0  ...           NaN          NaN             0
# 18696      1        1.0  ...         238.0          NaN             1
# 27710      1        0.0  ...        9013.0       9252.0             0
#
#        ISCORRECTCURRENT  TOTAL1  TOTAL2  BUTTON  MISSINGDATA  people_count  \
# 18457               1.0       1       0     1.0            0             2
# 18696               1.0       0       1     2.0            0             2
# 27710               1.0       1       0     1.0            0             2
#
#        animal_count
# 18457             0
# 18696             0
# ...
